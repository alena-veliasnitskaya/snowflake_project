# %%
import pandas as pd

# %%
df = pd.read_csv('763K_plus_IOS_Apps_Info.csv')

# %%
df.to_csv('data.csv', index = False)

# %%
df = pd.read_csv('data.csv')
# Out:
#                              _id  IOS_App_Id  \
# 0       5ddd0f935add2aa7a436dfa3  1224614786
# 1       5ddd0f935add2aa7a436dfa4  1111182407
# 2       5ddd0f935add2aa7a436dfa5  1203161394
# 3       5ddd0f935add2aa7a436dfa6  1257965362
# 4       5ddd0f935add2aa7a436dfa7  1143009457
# ...                          ...         ...
# 763826  5e5fa9cf17bb6c34a123b007  1022210934
# 763827  5e5fa9cf17bb6c34a123b008  1368479683
# 763828  5e5fa9cf17bb6c34a123b009  1005051110
# 763829  5e5fa9cf17bb6c34a123b00a   824070217
# 763830  5e5fa9cf17bb6c34a123b00b  1250342712
#
#                                                     Title  \
# 0       abc - writing style cursive flashcards worksheets
# 1                                               abcForAll
# 2                                            abcForAll tw
# 3                                      abegs books reader
# 4                             aBooks - Sách Truyện Online
# ...                                                   ...
# ...

# %%
df['Developer_Name'] = df['Developer_Name'].str.replace(',', ';')
df['Title'] = df['Title'].str.replace(',', ';')
df['All_Genres'] = df['All_Genres'].str.replace(',', ';')
df['Languages'] = df['Languages'].str.replace(',', ';')
df['Description'] = df['Description'].str.replace(',', ';')
df['_id'] = df['_id'].str.replace(',', ';')
df['IOS_Store_Url'] = df['IOS_Store_Url'].str.replace(',', ';')
df['Seller_Official_Website'] = df['Seller_Official_Website'].str.replace(',', ';')
df['Age_Rating'] = df['Age_Rating'].str.replace(',', ';')
df['Original_Release_Date'] = df['Original_Release_Date'].str.replace(',', ';')
df['Current_Version_Release_Date'] = df['Current_Version_Release_Date'].str.replace(',', ';')
# Out:
#                              _id  IOS_App_Id  \
# 0       5ddd0f935add2aa7a436dfa3  1224614786
# 1       5ddd0f935add2aa7a436dfa4  1111182407
# 2       5ddd0f935add2aa7a436dfa5  1203161394
# 3       5ddd0f935add2aa7a436dfa6  1257965362
# 4       5ddd0f935add2aa7a436dfa7  1143009457
# ...                          ...         ...
# 763826  5e5fa9cf17bb6c34a123b007  1022210934
# 763827  5e5fa9cf17bb6c34a123b008  1368479683
# 763828  5e5fa9cf17bb6c34a123b009  1005051110
# 763829  5e5fa9cf17bb6c34a123b00a   824070217
# 763830  5e5fa9cf17bb6c34a123b00b  1250342712
#
#                                                     Title  \
# 0       abc - writing style cursive flashcards worksheets
# 1                                               abcForAll
# 2                                            abcForAll tw
# 3                                      abegs books reader
# 4                             aBooks - Sách Truyện Online
# ...                                                   ...
# ...

# %%
df[[ 'IOS_App_Id', 'Developer_IOS_Id']] = df[['IOS_App_Id','Developer_IOS_Id']].astype(str)

# %%
df['IOS_App_Id'] = df['IOS_App_Id'].str.replace(',', '')

# %%
df['Developer_IOS_Id'] = df['Developer_IOS_Id'].str.replace(',', '')

# %%
df.to_csv('data.csv', index = False)

# %%
df['All_Genres'] = df['All_Genres'].str.replace('[', '')
df['Languages'] = df['Languages'].str.replace('[', '')
df['All_Genres'] = df['All_Genres'].str.replace(']', '')
df['Languages'] = df['Languages'].str.replace(']', '')
# Out:
# /tmp/ipykernel_17876/2782712422.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['All_Genres'] = df['All_Genres'].str.replace('[', '')
# /tmp/ipykernel_17876/2782712422.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Languages'] = df['Languages'].str.replace('[', '')
# /tmp/ipykernel_17876/2782712422.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['All_Genres'] = df['All_Genres'].str.replace(']', '')
# ...

# %%
df['All_Genres'] = df['All_Genres'].str.replace('"', '')
df['Languages'] = df['Languages'].str.replace('"', '')
df['Description'] = df['Description'].str.replace('"', '')
